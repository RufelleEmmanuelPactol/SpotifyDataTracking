# %%
import seaborn as st 
import pandas as pd
import chromadb

def refresh():
    return pd.read_csv('top_50_2023.csv')
df = refresh()
df
# Out:
#            artist_name                                         track_name  \
# 0          Miley Cyrus                                            Flowers
# 1                  SZA                                          Kill Bill
# 2         Harry Styles                                          As It Was
# 3            Jung Kook                Seven (feat. Latto) (Explicit Ver.)
# 4       Eslabon Armado                                    Ella Baila Sola
# 5         Taylor Swift                                       Cruel Summer
# 6         Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 7                 Rema                      Calm Down (with Selena Gomez)
# 8             Bizarrap              Shakira: Bzrp Music Sessions, Vol. 53
# 9         Taylor Swift                                          Anti-Hero
# 10      Arctic Monkeys                                   I Wanna Be Yours
# 11             KAROL G                                                TQG
# 12           Yng Lvcas                                    La Bebe - Remix
# 13        David Guetta                                    I'm Good (Blue)
# 14          The Weeknd                                        Die For You
# 15      Grupo Frontera                                          un x100to
# 16           Sam Smith                          Unholy (feat. Kim Petras)
# 17       Manuel Turizo                                         La Bachata
# 18      PinkPantheress                                 Boy's a liar Pt. 2
# 19       David Kushner                                           Daylight
# 20           Tom Odell                                       Another Love
# 21          The Weeknd                                            Starboy
# 22              Yandel                                         Yandel 150
# 23         FIFTY FIFTY                                  Cupid - Twin Ver.
# 24          The Weeknd           Die For You (with Ariana Grande) - Remix
# 25         OneRepublic                                    I Ain't Worried
# 26                d4vd                                       Here With Me
# 27       Morgan Wallen                                         Last Night
# 28                JVKE                                        golden hour
# 29     Stephen Sanchez  Until I Found You (with Em Beihold) - Em Beiho...
# 30         Myke Towers                                               LALA
# 31            Bizarrap              Quevedo: Bzrp Music Sessions, Vol. 52
# 32               Ozuna                                            Hey Mor
# 33                Feid                                         CLASSY 101
# 34            Doja Cat                                 Paint The Town Red
# 35   The Neighbourhood                                    Sweater Weather
# 36                 SZA                                             Snooze
# 37        Taylor Swift                                        Blank Space
# 38          The Weeknd                                    Blinding Lights
# 39           Bad Bunny                                     WHERE SHE GOES
# 40               Jimin                                         Like Crazy
# 41              Eminem                                        Mockingbird
# 42                RAYE                                          Escapism.
# 43      Olivia Rodrigo                                            vampire
# 44          Peso Pluma                                                PRC
# 45  Tyler, The Creator                   See You Again (feat. Kali Uchis)
# 46           Bad Bunny                                    Me Porto Bonito
# 47            NewJeans                                                OMG
# 48       Natanael Cano                                                AMG
# 49                d4vd                                  Romantic Homicide
#
#     is_explicit album_release_date  \
# 0         False         2023-08-18
# 1         False         2022-12-08
# 2         False         2022-05-20
# 3          True         2023-11-03
# 4         False         2023-04-28
# 5         False         2019-08-23
# 6          True         2022-12-02
# 7         False         2023-04-27
# 8         False         2023-01-11
# 9         False         2022-10-21
# 10        False         2013-09-09
# 11         True         2023-02-24
# 12         True         2023-03-17
# 13         True         2022-08-26
# 14        False         2016-11-24
# 15        False         2023-08-25
# 16        False         2023-01-27
# 17        False         2023-03-17
# 18         True         2023-11-10
# 19        False         2023-04-14
# 20         True         2013-06-24
# 21         True         2016-11-25
# 22         True         2023-01-13
# 23        False         2023-09-22
# 24        False         2023-03-14
# 25        False         2022-05-13
# 26        False         2023-05-26
# 27         True         2023-03-03
# 28        False         2022-09-23
# 29        False         2022-04-22
# 30         True         2023-03-23
# 31        False         2022-07-06
# 32        False         2022-10-07
# 33         True         2023-03-31
# 34         True         2023-09-20
# 35        False         2013-04-19
# 36         True         2022-12-09
# 37        False         2014-10-27
# 38        False         2020-03-20
# 39         True         2023-10-13
# 40        False         2023-03-24
# 41         True         2004-11-12
# 42         True         2023-02-03
# 43         True         2023-09-08
# 44         True         2023-06-29
# 45         True         2017-07-21
# 46         True         2022-05-06
# 47        False         2023-01-02
# 48         True         2023-06-30
# 49        False         2022-07-20
#
#                                                genres  danceability  valence  \
# 0                                             ['pop']         0.706    0.632
# 1                               ['pop', 'r&b', 'rap']         0.644    0.418
# 2                                             ['pop']         0.520    0.662
# 3                                           ['k-pop']         0.790    0.872
# 4   ['corrido', 'corridos tumbados', 'sad sierreno...         0.668    0.834
# 5                                             ['pop']         0.552    0.564
# 6                                             ['rap']         0.715    0.172
# 7                       ['afrobeats', 'nigerian pop']         0.799    0.811
# 8   ['argentine hip hop', 'pop venezolano', 'trap ...         0.778    0.498
# 9                                             ['pop']         0.637    0.533
# 10  ['garage rock', 'modern rock', 'permanent wave...         0.464    0.479
# 11  ['reggaeton', 'reggaeton colombiano', 'trap la...         0.720    0.607
# 12                   ['reggaeton', 'urbano mexicano']         0.812    0.559
# 13  ['big room', 'dance pop', 'edm', 'pop', 'pop d...         0.561    0.304
# 14  ['canadian contemporary r&b', 'canadian pop', ...         0.586    0.508
# 15                            ['musica chihuahuense']         0.571    0.542
# 16                                  ['pop', 'uk pop']         0.712    0.206
# 17  ['colombian pop', 'latin pop', 'reggaeton', 'r...         0.835    0.850
# 18                                    ['bedroom pop']         0.696    0.857
# 19  ['gen z singer-songwriter', 'singer-songwriter...         0.508    0.324
# 20                                      ['chill pop']         0.445    0.131
# 21  ['canadian contemporary r&b', 'canadian pop', ...         0.679    0.486
# 22  ['latin hip hop', 'reggaeton', 'trap latino', ...         0.783    0.580
# 23                               ['k-pop girl group']         0.783    0.726
# 24  ['canadian contemporary r&b', 'canadian pop', ...         0.575    0.506
# 25                              ['piano rock', 'pop']         0.704    0.825
# 26                                    ['bedroom pop']         0.571    0.299
# 27                           ['contemporary country']         0.492    0.478
# 28  ['modern indie pop', 'pov: indie', 'singer-son...         0.515    0.153
# 29                        ['gen z singer-songwriter']         0.551    0.342
# 30      ['reggaeton', 'trap latino', 'urbano latino']         0.708    0.607
# 31  ['argentine hip hop', 'pop venezolano', 'trap ...         0.621    0.550
# 32  ['puerto rican pop', 'reggaeton', 'trap latino...         0.901    0.399
# 33  ['colombian pop', 'pop reggaeton', 'reggaeton'...         0.859    0.672
# 34                               ['dance pop', 'pop']         0.864    0.726
# 35  ['modern alternative rock', 'modern rock', 'pop']         0.612    0.398
# 36                              ['pop', 'r&b', 'rap']         0.559    0.392
# 48   11  136.175     0       174943               3          81
# 49    6  132.052     1       132631               4          91

# %% [markdown]
# ## Pop-Extraction
# Let's filter the data such that we are only including pop and pop-adjacent genres. Since it is impossible for us to this manually, we will use the chromadb to filter the data for us, through semantic analysis.

# %%
client = chromadb.Client()
collection = client.create_collection('genres')
collection.add(
    documents=['pop', 'ballad', 'jazz', 'country', 'traditional'],
    ids=['1', '2', '3', '4', '5']
)

"Finished adding documents to collection"
# Out:
# ---------------------------------------------------------------------------
# UniqueConstraintError                     Traceback (most recent call last)
# Cell In[42], line 2
#       1 client = chromadb.Client()
# ----> 2 collection = client.create_collection('genres')
#       3 collection.add(
#       4     documents=['pop', 'ballad', 'jazz', 'country', 'traditional'],
#       5     ids=['1', '2', '3', '4', '5']
#       6 )
#       8 "Finished adding documents to collection"
#
# File ~/DataspellProjects/IS2PRJ1/venv/lib/python3.9/site-packages/chromadb/api/client.py:198, in Client.create_collection(self, name, metadata, embedding_function, data_loader, get_or_create)
#     187 @override
#     188 def create_collection(
#     189     self,
#    (...)
#     196     get_or_create: bool = False,
#     197 ) -> Collection:
# --> 198     return self._server.create_collection(
#     199         name=name,
#     200         metadata=metadata,
#     201         embedding_function=embedding_function,
#     202         data_loader=data_loader,
#     203         tenant=self.tenant,
#     204         database=self.database,
#     205         get_or_create=get_or_create,
#     206     )
#
# File ~/DataspellProjects/IS2PRJ1/venv/lib/python3.9/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/DataspellProjects/IS2PRJ1/venv/lib/python3.9/site-packages/chromadb/api/segment.py:166, in SegmentAPI.create_collection(self, name, metadata, embedding_function, data_loader, get_or_create, tenant, database)
#     162 check_index_name(name)
#     164 id = uuid4()
# --> 166 coll, created = self._sysdb.create_collection(
#     167     id=id,
#     168     name=name,
#     169     metadata=metadata,
#     170     dimension=None,
#     171     get_or_create=get_or_create,
#     172     tenant=tenant,
#     173     database=database,
#     174 )
#     176 if created:
#     177     segments = self._manager.create_segments(coll)
#
# File ~/DataspellProjects/IS2PRJ1/venv/lib/python3.9/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/DataspellProjects/IS2PRJ1/venv/lib/python3.9/site-packages/chromadb/db/mixins/sysdb.py:225, in SqlSysDB.create_collection(self, id, name, metadata, dimension, get_or_create, tenant, database)
#     218         return (
#     219             self.get_collections(
#     220                 id=collection["id"], tenant=tenant, database=database
#     221             )[0],
#     222             False,
#     223         )
#     224     else:
# --> 225         raise UniqueConstraintError(f"Collection {name} already exists")
#     227 topic = self._assignment_policy.assign_collection(id)
#     228 collection = Collection(
#     229     id=id,
#     230     topic=topic,
#    (...)
#     235     database=database,
#     236 )
#
# UniqueConstraintError: Collection genres already exists

# %%
# Out:
# "['pop']"

# %%
# Let's use the collection to filter the data
import ast 

def get_genres(genre_string: str) -> list:
    return ast.literal_eval(genre_string)

def process_genres(entry):
    genres = get_genres(entry)
    
    def is_valid(genres):
        results = collection.query(query_texts=genres, n_results=1)['documents']
        valid = False
        for result in results:
            if result[0] == 'pop':
                valid = True
                
        return valid
    return is_valid(genres)

df['is_pop'] = df.genres.apply(process_genres)
df.head(15)
# Out:
#        artist_name                              track_name  is_explicit  \
# 0      Miley Cyrus                                 Flowers        False
# 1              SZA                               Kill Bill        False
# 2     Harry Styles                               As It Was        False
# 3        Jung Kook     Seven (feat. Latto) (Explicit Ver.)         True
# 4   Eslabon Armado                         Ella Baila Sola        False
# 5     Taylor Swift                            Cruel Summer        False
# 6     Metro Boomin  Creepin' (with The Weeknd & 21 Savage)         True
# 7             Rema           Calm Down (with Selena Gomez)        False
# 8         Bizarrap   Shakira: Bzrp Music Sessions, Vol. 53        False
# 9     Taylor Swift                               Anti-Hero        False
# 10  Arctic Monkeys                        I Wanna Be Yours        False
# 11         KAROL G                                     TQG         True
# 12       Yng Lvcas                         La Bebe - Remix         True
# 13    David Guetta                         I'm Good (Blue)         True
# 14      The Weeknd                             Die For You        False
#
#    album_release_date                                             genres  \
# 0          2023-08-18                                            ['pop']
# 1          2022-12-08                              ['pop', 'r&b', 'rap']
# 2          2022-05-20                                            ['pop']
# 3          2023-11-03                                          ['k-pop']
# 4          2023-04-28  ['corrido', 'corridos tumbados', 'sad sierreno...
# 5          2019-08-23                                            ['pop']
# 6          2022-12-02                                            ['rap']
# 7          2023-04-27                      ['afrobeats', 'nigerian pop']
# 8          2023-01-11  ['argentine hip hop', 'pop venezolano', 'trap ...
# 9          2022-10-21                                            ['pop']
# 10         2013-09-09  ['garage rock', 'modern rock', 'permanent wave...
# 11         2023-02-24  ['reggaeton', 'reggaeton colombiano', 'trap la...
# 12         2023-03-17                   ['reggaeton', 'urbano mexicano']
# 13         2022-08-26  ['big room', 'dance pop', 'edm', 'pop', 'pop d...
# 14         2016-11-24  ['canadian contemporary r&b', 'canadian pop', ...
#
#     danceability  valence  energy  loudness  acousticness  instrumentalness  \
# 0          0.706    0.632   0.691    -4.775       0.05840          0.000070
# 1          0.644    0.418   0.735    -5.747       0.05210          0.144000
# 2          0.520    0.662   0.731    -5.338       0.34200          0.001010
# 3          0.790    0.872   0.831    -4.185       0.31200          0.000000
# 4          0.668    0.834   0.758    -5.176       0.48300          0.000019
# 5          0.552    0.564   0.702    -5.707       0.11700          0.000021
# 6          0.715    0.172   0.620    -6.005       0.41700          0.000000
# 7          0.799    0.811   0.802    -5.196       0.42900          0.001280
# 8          0.778    0.498   0.632    -5.600       0.27400          0.000000
# 9          0.637    0.533   0.643    -6.571       0.13000          0.000002
# 10         0.464    0.479   0.417    -9.345       0.13600          0.022000
# 11         0.720    0.607   0.630    -3.547       0.67300          0.000000
# 12         0.812    0.559   0.479    -5.678       0.21300          0.000001
# 13         0.561    0.304   0.965    -3.673       0.00383          0.000007
# 14         0.586    0.508   0.525    -7.163       0.11100          0.000000
#
#     liveness  speechiness  key    tempo  mode  duration_ms  time_signature  \
# 0     0.0232       0.0633    0  118.048     1       200600               4
# 1     0.1610       0.0391    8   88.980     1       153947               4
# 2     0.3110       0.0557    6  173.930     0       167303               4
# 3     0.0797       0.0440   11  124.987     1       183551               4
# 4     0.0837       0.0332    5  147.989     0       165671               3
# 5     0.1050       0.1570    9  169.994     1       178427               4
# 6     0.0822       0.0484    1   97.950     0       221520               4
# 7     0.1710       0.0371   11  107.008     1       239318               4
# 8     0.0915       0.0493    2  122.104     0       218289               4
# 9     0.1420       0.0519    4   97.008     1       200690               4
# 10    0.0974       0.0256    0   67.528     0       183956               4
# 11    0.0936       0.2770    4  179.974     0       199440               4
# 12    0.0756       0.3330    2  169.922     0       234353               4
# 13    0.3710       0.0343    7  128.040     0       175238               4
# 14    0.1340       0.0615    1  133.629     0       260253               4
#
#     popularity  is_pop
# 0           94    True
# 1           86    True
# 2           95    True
# 3           90    True
# 4           86   False
# 5           99    True
# 6           91   False
# 7           90    True
# 8           85    True
# 9           92    True
# 10          96    True
# 11          88   False
# 12          89   False
# 13          92    True
# 14          85    True

# %%
# Let's create a correlation matrix using the non-discrete columns inside the original dataframe
non_discrete_columns =('Medu', 'Fedu', 'traveltime', 'studytime', 'failures','famrel', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'score')
nd_df = pd.DataFrame(df, columns=non_discrete_columns)
nd_df.corr()
# Out:
#                 Medu      Fedu  traveltime  studytime  failures    famrel  \
# Medu        1.000000  0.626971   -0.171440   0.069349 -0.240133 -0.003967
# Fedu        0.626971  1.000000   -0.157267  -0.004909 -0.253591 -0.001369
# traveltime -0.171440 -0.157267    1.000000  -0.103097  0.092865 -0.016533
# studytime   0.069349 -0.004909   -0.103097   1.000000 -0.175752  0.039454
# failures   -0.240133 -0.253591    0.092865  -0.175752  1.000000 -0.044210
# famrel     -0.003967 -0.001369   -0.016533   0.039454 -0.044210  1.000000
# goout       0.069967  0.049061    0.028046  -0.060629  0.120980  0.064404
# Dalc        0.020341  0.002427    0.135853  -0.193763  0.135167 -0.077706
# Walc       -0.051924 -0.017925    0.132782  -0.254491  0.143935 -0.113279
# health     -0.051914  0.009615    0.008754  -0.078549  0.068448  0.094008
# absences    0.102713  0.026982   -0.014265  -0.060321  0.061946 -0.044431
# score       0.226116  0.176404   -0.134732   0.139799 -0.376513  0.021418
#
#                goout      Dalc      Walc    health  absences     score
# Medu        0.069967  0.020341 -0.051924 -0.051914  0.102713  0.226116
# Fedu        0.049061  0.002427 -0.017925  0.009615  0.026982  0.176404
# traveltime  0.028046  0.135853  0.132782  0.008754 -0.014265 -0.134732
# studytime  -0.060629 -0.193763 -0.254491 -0.078549 -0.060321  0.139799
# failures    0.120980  0.135167  0.143935  0.068448  0.061946 -0.376513
# famrel      0.064404 -0.077706 -0.113279  0.094008 -0.044431  0.021418
# goout       1.000000  0.266512  0.415407 -0.012968  0.046053 -0.150704
# Dalc        0.266512  1.000000  0.646612  0.076130  0.112675 -0.067616
# Walc        0.415407  0.646612  1.000000  0.094640  0.134889 -0.086102
# health     -0.012968  0.076130  0.094640  1.000000 -0.031783 -0.084251
# absences    0.046053  0.112675  0.134889 -0.031783  1.000000 -0.001181
# score      -0.150704 -0.067616 -0.086102 -0.084251 -0.001181  1.000000
